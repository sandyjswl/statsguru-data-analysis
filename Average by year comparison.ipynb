# %%
import json
import pandas as pd
import collections

# %%
with open("/Users/sandeep.jaiswal/PycharmProjects/cric-service/data.json","r") as fp:
    data =json.load(fp)

# %%
data = collections.OrderedDict(sorted(data.items()))

# %%
data
# Out:
# OrderedDict([('Test # 1997',
#               {'4s': '3',
#                'Bat1': '4',
#                'Opposition': 'v West Indies',
#                'Bat2': '15',
#                'Start Date': '20 Jun 2011',
#                'Ground': 'Kingston',
#                'BF': '64',
#                'Runs': '19',
#                '6s': '0',
#                'SR': '29.68'}),
#              ('Test # 1998',
#               {'BF': '109',
#                'Runs': '27',
#                'SR': '24.77',
#                '6s': '1',
#                '4s': '1',
#                'Bat1': '0',
#                'Opposition': 'v West Indies',
#                'Bat2': '27',
#                'Start Date': '28 Jun 2011',
#                'Ground': 'Bridgetown'}),
#              ('Test # 1999',
#               {'Start Date': '6 Jul 2011',
#                'Ground': 'Roseau',
#                'BF': '53',
#                'Runs': '30',
#                'SR': '56.60',
#                '6s': '0',
#                '4s': '2',
#                'Bat1': '30',
#                'Opposition': 'v West Indies',
#                'Bat2': 'DNB'}),
#              ('Test # 2019',
#               {'4s': '8',
#                'Opposition': 'v West Indies',
#                'Bat1': '52',
#                'Bat2': '63',
#                'Start Date': '22 Nov 2011',
#                'Ground': 'Mumbai',
#                'BF': '225',
#                'Runs': '115',
#                '6s': '1',
#                'SR': '51.11'}),
#              ('Test # 2025',
#               {'Start Date': '26 Dec 2011',
#                'Ground': 'Melbourne',
#                'BF': '22',
#                'Runs': '11',
#                'SR': '50.00',
#                '6s': '0',
#                '4s': '1',
#                'Bat1': '11',
#                'Opposition': 'v Australia',
#                'Bat2': '0'}),
#              ('Test # 2027',
#               {'4s': '5',
#                'Opposition': 'v Australia',
#                'Bat1': '23',
#                'Bat2': '9',
#                'Start Date': '3 Jan 2012',
#                'Ground': 'Sydney',
#                'Runs': '32',
#                'BF': '65',
#                '6s': '0',
#                'SR': '49.23'}),
#              ('Test # 2029',
#               {'4s': '15',
#                'Bat1': '44',
#                'Opposition': 'v Australia',
#                'Bat2': '75',
#                'Start Date': '13 Jan 2012',
#                'Ground': 'Perth',
#                'BF': '217',
#                'Runs': '119',
#                'SR': '54.83',
#                '6s': '0'}),
#              ('Test # 2031',
#               {'Start Date': '24 Jan 2012',
#                'Ground': 'Adelaide',
#                'BF': '275',
#                'Runs': '138',
#                '6s': '1',
#                'SR': '50.18',
#                '4s': '13',
#                'Bat1': '116',
#                'Opposition': 'v Australia',
#                'Bat2': '22'}),
#              ('Test # 2054',
#               {'4s': '8',
#                'Opposition': 'v New Zealand',
#                'Bat1': '58',
#                'Bat2': '-',
#                'Start Date': '23 Aug 2012',
#                'Ground': 'Hyderabad (Deccan)',
#                'BF': '107',
#                'Runs': '58',
#                '6s': '0',
#                'SR': '54.20'}),
#              ('Test # 2055',
#               {'Bat1': '103',
#                'Opposition': 'v New Zealand',
#                'Bat2': '51*',
#                'Start Date': '31 Aug 2012',
#                'Ground': 'Bengaluru',
#                'BF': '275',
#                'Runs': '154',
#                'SR': '56.00',
#                '6s': '1',
#                '4s': '23'}),
#              ('Test # 2058',
#               {'4s': '6',
#                'Bat1': '19',
#                'Opposition': 'v England',
#                'Bat2': '14*',
#                'Start Date': '15 Nov 2012',
#                'Ground': 'Ahmedabad',
#                'BF': '88',
#                'Runs': '33',
#                'SR': '37.50',
#                '6s': '0'}),
#              ('Test # 2062',
#               {'BF': '68',
#                'Runs': '26',
#                '6s': '0',
#                'SR': '38.23',
#                '4s': '4',
#                'Bat1': '19',
#                'Opposition': 'v England',
#                'Bat2': '7',
#                'Start Date': '23 Nov 2012',
#                'Ground': 'Mumbai'}),
#              ('Test # 2065',
#               {'4s': '4',
#                'Bat1': '6',
#                'Opposition': 'v England',
#                'Bat2': '20',
#                'Start Date': '5 Dec 2012',
#                'Ground': 'Kolkata',
#                'Runs': '26',
#                'BF': '84',
#                'SR': '30.95',
#                '6s': '0'}),
#              ('Test # 2066',
#               {'Ground': 'Nagpur',
#                'BF': '295',
#                'Runs': '103',
#                'SR': '34.91',
#                '6s': '0',
#                '4s': '11',
#                'Bat1': '103',
#                'Opposition': 'v England',
#                'Bat2': '-',
#                'Start Date': '13 Dec 2012'}),
#              ('Test # 2074',
#               {'Start Date': '22 Feb 2013',
#                'Ground': 'Chennai',
#                'Runs': '107',
#                'BF': '206',
#                '6s': '1',
#                'SR': '51.94',
#                '4s': '15',
#                'Opposition': 'v Australia',
#                'Bat1': '107',
#                'Bat2': 'DNB'}),
#              ('Test # 2076',
#               {'Ground': 'Hyderabad (Deccan)',
#                'BF': '92',
#                'Runs': '34',
#                'SR': '36.95',
#                '6s': '0',
#                '4s': '3',
#                'Bat1': '34',
#                'Opposition': 'v Australia',
#                'Bat2': '-',
#                'Start Date': '2 Mar 2013'}),
#              ('Test # 2081',
#               {'4s': '13',
#                'Bat1': '67*',
#                'Opposition': 'v Australia',
#                'Bat2': '34',
#                'Start Date': '14 Mar 2013',
#                'Ground': 'Mohali',
#                'BF': '190',
#                'Runs': '101',
#                '6s': '1',
#                'SR': '53.15'}),
#              ('Test # 2085',
#               {'Start Date': '22 Mar 2013',
#                'Ground': 'Delhi',
#                'BF': '68',
#                'Runs': '42',
#                'SR': '61.76',
#                '6s': '0',
#                '4s': '4',
#                'Bat1': '1',
#                'Opposition': 'v Australia',
#                'Bat2': '41'}),
#              ('Test # 2101',
#               {'Start Date': '6 Nov 2013',
#                'Ground': 'Kolkata',
#                'Runs': '3',
#                'BF': '5',
#                '6s': '0',
#                'SR': '60.00',
#                '4s': '0',
#                'Opposition': 'v West Indies',
#                'Bat1': '3',
#                'Bat2': '-'}),
#              ('Test # 2102',
#               {'4s': '5',
#                'Opposition': 'v West Indies',
#                'Bat1': '57',
#                'Bat2': '-',
#                'Start Date': '14 Nov 2013',
#                'Ground': 'Mumbai',
#                'BF': '78',
#                'Runs': '57',
#                '6s': '0',
#                'SR': '73.07'}),
#              ('Test # 2108',
#               {'Start Date': '18 Dec 2013',
#                'Ground': 'Johannesburg',
#                'BF': '374',
#                'Runs': '215',
#                'SR': '57.48',
#                '6s': '0',
#                '4s': '27',
#                'Bat1': '119',
#                'Opposition': 'v South Africa',
#                'Bat2': '96'}),
#              ('Test # 2111',
#               {'4s': '6',
#                'Bat1': '46',
#                'Opposition': 'v South Africa',
#                'Bat2': '11',
#                'Start Date': '26 Dec 2013',
#                'Ground': 'Durban',
#                'Runs': '57',
#                'BF': '114',
#                'SR': '50.00',
#                '6s': '0'}),
#              ('Test # 2118',
#               {'Start Date': '6 Feb 2014',
#                'Ground': 'Auckland',
#                'BF': '115',
#                'Runs': '71',
#                '6s': '0',
#                'SR': '61.73',
#                '4s': '13',
#                'Opposition': 'v New Zealand',
#                'Bat1': '4',
#                'Bat2': '67'}),
#              ('Test # 2120',
#               {'Start Date': '14 Feb 2014',
#                'Ground': 'Wellington',
#                'BF': '228',
#                'Runs': '143',
#                '6s': '1',
#                'SR': '62.71',
#                '4s': '19',
#                'Bat1': '38',
#                'Opposition': 'v New Zealand',
#                'Bat2': '105*'}),
#              ('Test # 2128',
#               {'4s': '1',
#                'Bat1': '1',
#                'Opposition': 'v England',
#                'Bat2': '8',
#                'Start Date': '9 Jul 2014',
#                'Ground': 'Nottingham',
#                'BF': '37',
#                'Runs': '9',
#                '6s': '0',
#                'SR': '24.32'}),
#              ('Test # 2130',
#               {'BF': '35',
#                'Runs': '25',
#                'SR': '71.42',
#                '6s': '0',
#                '4s': '4',
#                'Bat1': '25',
#                'Opposition': 'v England',
#                'Bat2': '0',
#                'Start Date': '17 Jul 2014',
#                'Ground': "Lord's"}),
#              ('Test # 2132',
#               {'4s': '6',
#                'Bat1': '39',
#                'Opposition': 'v England',
#                'Bat2': '28',
#                'Start Date': '27 Jul 2014',
#                'Ground': 'Southampton',
#                'BF': '131',
#                'Runs': '67',
#                '6s': '0',
#                'SR': '51.14'}),
#              ('Test # 2134',
#               {'Start Date': '7 Aug 2014',
#                'Ground': 'Manchester',
#                'BF': '13',
#                'Runs': '7',
#                '6s': '0',
#                'SR': '53.84',
#                '4s': '1',
#                'Bat1': '0',
#                'Opposition': 'v England',
#                'Bat2': '7'}),
#              ('Test # 2137',
#               {'4s': '3',
#                'Opposition': 'v England',
#                'Bat1': '6',
#                'Bat2': '20',
#                'Start Date': '15 Aug 2014',
#                'Ground': 'The Oval',
#                'Runs': '26',
#                'BF': '72',
#                '6s': '0',
#                'SR': '36.11'}),
#              ('Test # 2148',
#               {'4s': '28',
#                'Opposition': 'v Australia',
#                'Bat1': '115',
#                'Bat2': '141',
#                'Start Date': '9 Dec 2014',
#                'Ground': 'Adelaide',
#                'Runs': '256',
#                'BF': '359',
#                '6s': '1',
#                'SR': '71.30'}),
#              ('Test # 2149',
#               {'4s': '1',
#                'Bat1': '19',
#                'Opposition': 'v Australia',
#                'Bat2': '1',
#                'Start Date': '17 Dec 2014',
#                'Ground': 'Brisbane',
#                'Runs': '20',
#                'BF': '38',
#                'SR': '52.63',
#                '6s': '0'}),
#              ('Test # 2152',
#               {'4s': '25',
#                'Bat1': '169',
#                'Opposition': 'v Australia',
#                'Bat2': '54',
#                'Start Date': '26 Dec 2014',
#                'Ground': 'Melbourne',
#                'Runs': '223',
#                'BF': '371',
#                'SR': '60.10',
#                '6s': '0'}),
#              ('Test # 2156',
#               {'4s': '23',
#                'Bat1': '147',
#                'Opposition': 'v Australia',
#                'Bat2': '46',
#                'Start Date': '6 Jan 2015',
#                'Ground': 'Sydney',
#                'BF': '325',
#                'Runs': '193',
#                'SR': '59.38',
#                '6s': '0'}),
#              ('Test # 2165',
#               {'4s': '2',
#                'Bat1': '14',
#                'Opposition': 'v Bangladesh',
#                'Bat2': '-',
#                'Start Date': '10 Jun 2015',
#                'Ground': 'Fatullah',
#                'Runs': '14',
#                'BF': '22',
#                'SR': '63.63',
#                '6s': '0'}),
#              ('Test # 2176',
#               {'4s': '11',
#                'Bat1': '103',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '3',
#                'Start Date': '12 Aug 2015',
#                'Ground': 'Galle',
#                'BF': '201',
#                'Runs': '106',
#                'SR': '52.73',
#                '6s': '0'}),
#              ('Test # 2177',
#               {'Bat1': '78',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '10',
#                'Start Date': '20 Aug 2015',
#                'Ground': 'Colombo (PSS)',
#                'BF': '126',
#                'Runs': '88',
#                '6s': '1',
#                'SR': '69.84',
#                '4s': '8'}),
#              ('Test # 2179',
#               {'BF': '123',
#                'Runs': '39',
#                'SR': '31.70',
#                '6s': '0',
#                '4s': '5',
#                'Bat1': '18',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '21',
#                'Start Date': '28 Aug 2015',
#                'Ground': 'Colombo (SSC)'}),
#              ('Test # 2186',
#               {'Runs': '30',
#                'BF': '75',
#                'SR': '40.00',
#                '6s': '0',
#                '4s': '4',
#                'Bat1': '1',
#                'Opposition': 'v South Africa',
#                'Bat2': '29',
#                'Start Date': '5 Nov 2015',
#                'Ground': 'Mohali'}),
#              ('Test # 2188',
#               {'BF': '-',
#                'Runs': '-',
#                'SR': '-',
#                '6s': '-',
#                '4s': '-',
#                'Bat1': 'DNB',
#                'Opposition': 'v South Africa',
#                'Bat2': '-',
#                'Start Date': '14 Nov 2015',
#                'Ground': 'Bengaluru'}),
#              ('Test # 2189',
#               {'4s': '4',
#                'Opposition': 'v South Africa',
#                'Bat1': '22',
#                'Bat2': '16',
#                'Start Date': '25 Nov 2015',
#                'Ground': 'Nagpur',
#                'BF': '85',
#                'Runs': '38',
#                '6s': '0',
#                'SR': '44.70'}),
#              ('Test # 2191',
#               {'4s': '17',
#                'Bat1': '44',
#                'Opposition': 'v South Africa',
#                'Bat2': '88',
#                'Start Date': '3 Dec 2015',
#                'Ground': 'Delhi',
#                'BF': '227',
#                'Runs': '132',
#                '6s': '0',
#                'SR': '58.14'}),
#              ('Test # 2207',
#               {'Bat1': '200',
#                'Opposition': 'v West Indies',
#                'Bat2': '-',
#                'Start Date': '21 Jul 2016',
#                'Ground': 'North Sound',
#                'BF': '283',
#                'Runs': '200',
#                'SR': '70.67',
#                '6s': '0',
#                '4s': '24'}),
#              ('Test # 2211',
#               {'BF': '90',
#                'Runs': '44',
#                'SR': '48.88',
#                '6s': '1',
#                '4s': '4',
#                'Bat1': '44',
#                'Opposition': 'v West Indies',
#                'Bat2': '-',
#                'Start Date': '30 Jul 2016',
#                'Ground': 'Kingston'}),
#              ('Test # 2215',
#               {'4s': '0',
#                'Bat1': '3',
#                'Opposition': 'v West Indies',
#                'Bat2': '4',
#                'Start Date': '9 Aug 2016',
#                'Ground': 'Gros Islet',
#                'BF': '25',
#                'Runs': '7',
#                '6s': '0',
#                'SR': '28.00'}),
#              ('Test # 2218',
#               {'Start Date': '18 Aug 2016',
#                'Ground': 'Port of Spain',
#                'Runs': '-',
#                'BF': '-',
#                'SR': '-',
#                '6s': '-',
#                '4s': '-',
#                'Bat1': 'TDNB',
#                'Opposition': 'v West Indies',
#                'Bat2': '-'}),
#              ('Test # 2221',
#               {'4s': '5',
#                'Opposition': 'v New Zealand',
#                'Bat1': '9',
#                'Bat2': '18',
#                'Start Date': '22 Sep 2016',
#                'Ground': 'Kanpur',
#                'BF': '50',
#                'Runs': '27',
#                '6s': '0',
#                'SR': '54.00'}),
#              ('Test # 2222',
#               {'Ground': 'Kolkata',
#                'BF': '93',
#                'Runs': '54',
#                'SR': '58.06',
#                '6s': '0',
#                '4s': '8',
#                'Bat1': '9',
#                'Opposition': 'v New Zealand',
#                'Bat2': '45',
#                'Start Date': '30 Sep 2016'}),
#              ('Test # 2223',
#               {'Bat1': '211',
#                'Opposition': 'v New Zealand',
#                'Bat2': '17',
#                'Start Date': '8 Oct 2016',
#                'Ground': 'Indore',
#                'BF': '394',
#                'Runs': '228',
#                '6s': '0',
#                'SR': '57.86',
#                '4s': '21'}),
#              ('Test # 2232',
#               {'Start Date': '9 Nov 2016',
#                'Ground': 'Rajkot',
#                'Runs': '89',
#                'BF': '193',
#                'SR': '46.11',
#                '6s': '0',
#                '4s': '11',
#                'Bat1': '40',
#                'Opposition': 'v England',
#                'Bat2': '49*'}),
#              ('Test # 2235',
#               {'Start Date': '17 Nov 2016',
#                'Ground': 'Visakhapatnam',
#                'BF': '376',
#                'Runs': '248',
#                '6s': '0',
#                'SR': '65.95',
#                '4s': '26',
#                'Bat1': '167',
#                'Opposition': 'v England',
#                'Bat2': '81'}),
#              ('Test # 2238',
#               {'BF': '138',
#                'Runs': '68',
#                'SR': '49.27',
#                '6s': '0',
#                '4s': '9',
#                'Bat1': '62',
#                'Opposition': 'v England',
#                'Bat2': '6*',
#                'Start Date': '26 Nov 2016',
#                'Ground': 'Mohali'}),
#              ('Test # 2239',
#               {'Ground': 'Mumbai',
#                'BF': '340',
#                'Runs': '235',
#                'SR': '69.11',
#                '6s': '1',
#                '4s': '25',
#                'Bat1': '235',
#                'Opposition': 'v England',
#                'Bat2': '-',
#                'Start Date': '8 Dec 2016'}),
#              ('Test # 2241',
#               {'Ground': 'Chennai',
#                'BF': '29',
#                'Runs': '15',
#                '6s': '0',
#                'SR': '51.72',
#                '4s': '1',
#                'Bat1': '15',
#                'Opposition': 'v England',
#                'Bat2': '-',
#                'Start Date': '16 Dec 2016'}),
#              ('Test # 2249',
#               {'4s': '26',
#                'Bat1': '204',
#                'Opposition': 'v Bangladesh',
#                'Bat2': '38',
#                'Start Date': '9 Feb 2017',
#                'Ground': 'Hyderabad (Deccan)',
#                'BF': '286',
#                'Runs': '242',
#                '6s': '1',
#                'SR': '84.61'}),
#              ('Test # 2250',
#               {'Opposition': 'v Australia',
#                'Bat1': '0',
#                'Bat2': '13',
#                'Start Date': '23 Feb 2017',
#                'Ground': 'Pune',
#                'BF': '39',
#                'Runs': '13',
#                '6s': '0',
#                'SR': '33.33',
#                '4s': '1'}),
#              ('Test # 2251',
#               {'4s': '3',
#                'Opposition': 'v Australia',
#                'Bat1': '12',
#                'Bat2': '15',
#                'Start Date': '4 Mar 2017',
#                'Ground': 'Bengaluru',
#                'BF': '42',
#                'Runs': '27',
#                '6s': '0',
#                'SR': '64.28'}),
#              ('Test # 2256',
#               {'BF': '23',
#                'Runs': '6',
#                'SR': '26.08',
#                '6s': '0',
#                '4s': '0',
#                'Bat1': '6',
#                'Opposition': 'v Australia',
#                'Bat2': '-',
#                'Start Date': '16 Mar 2017',
#                'Ground': 'Ranchi'}),
#              ('Test # 2265',
#               {'Start Date': '26 Jul 2017',
#                'Ground': 'Galle',
#                'BF': '144',
#                'Runs': '106',
#                'SR': '73.61',
#                '6s': '1',
#                '4s': '5',
#                'Bat1': '3',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '103*'}),
#              ('Test # 2267',
#               {'Start Date': '3 Aug 2017',
#                'Ground': 'Colombo (SSC)',
#                'BF': '29',
#                'Runs': '13',
#                '6s': '0',
#                'SR': '44.82',
#                '4s': '2',
#                'Bat1': '13',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '-'}),
#              ('Test # 2269',
#               {'BF': '84',
#                'Runs': '42',
#                'SR': '50.00',
#                '6s': '0',
#                '4s': '3',
#                'Bat1': '42',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '-',
#                'Start Date': '12 Aug 2017',
#                'Ground': 'Pallekele'}),
#              ('Test # 2281',
#               {'Ground': 'Kolkata',
#                'BF': '130',
#                'Runs': '104',
#                '6s': '2',
#                'SR': '80.00',
#                '4s': '12',
#                'Bat1': '0',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '104*',
#                'Start Date': '16 Nov 2017'}),
#              ('Test # 2283',
#               {'4s': '17',
#                'Bat1': '213',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '-',
#                'Start Date': '24 Nov 2017',
#                'Ground': 'Nagpur',
#                'BF': '267',
#                'Runs': '213',
#                '6s': '2',
#                'SR': '79.77'}),
#              ('Test # 2286',
#               {'4s': '28',
#                'Bat1': '243',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '50',
#                'Start Date': '2 Dec 2017',
#                'Ground': 'Delhi',
#                'BF': '345',
#                'Runs': '293',
#                'SR': '84.92',
#                '6s': '0'}),
#              ('Test # 2292',
#               {'Opposition': 'v South Africa',
#                'Bat1': '5',
#                'Bat2': '28',
#                'Start Date': '5 Jan 2018',
#                'Ground': 'Cape Town',
#                'Runs': '33',
#                'BF': '53',
#                '6s': '0',
#                'SR': '62.26',
#                '4s': '4'}),
#              ('Test # 2293',
#               {'Start Date': '13 Jan 2018',
#                'Ground': 'Centurion',
#                'BF': '237',
#                'Runs': '158',
#                'SR': '66.66',
#                '6s': '0',
#                '4s': '16',
#                'Bat1': '153',
#                'Opposition': 'v South Africa',
#                'Bat2': '5'}),
#              ('Test # 2294',
#               {'BF': '185',
#                'Runs': '95',
#                'SR': '51.35',
#                '6s': '0',
#                '4s': '15',
#                'Bat1': '54',
#                'Opposition': 'v South Africa',
#                'Bat2': '41',
#                'Start Date': '24 Jan 2018',
#                'Ground': 'Johannesburg'}),
#              ('Test # 2314',
#               {'Bat1': '149',
#                'Opposition': 'v England',
#                'Bat2': '51',
#                'Start Date': '1 Aug 2018',
#                'Ground': 'Birmingham',
#                'BF': '318',
#                'Runs': '200',
#                '6s': '1',
#                'SR': '62.89',
#                '4s': '26'}),
#              ('Test # 2315',
#               {'BF': '86',
#                'Runs': '40',
#                'SR': '46.51',
#                '6s': '0',
#                '4s': '4',
#                'Bat1': '23',
#                'Opposition': 'v England',
#                'Bat2': '17',
#                'Start Date': '9 Aug 2018',
#                'Ground': "Lord's"}),
#              ('Test # 2316',
#               {'Bat1': '97',
#                'Opposition': 'v England',
#                'Bat2': '103',
#                'Start Date': '18 Aug 2018',
#                'Ground': 'Nottingham',
#                'BF': '349',
#                'Runs': '200',
#                'SR': '57.30',
#                '6s': '0',
#                '4s': '21'}),
#              ('Test # 2317',
#               {'Start Date': '30 Aug 2018',
#                'Ground': 'Southampton',
#                'Runs': '104',
#                'BF': '201',
#                '6s': '0',
#                'SR': '51.74',
#                '4s': '10',
#                'Opposition': 'v England',
#                'Bat1': '46',
#                'Bat2': '58'}),
#              ('Test # 2318',
#               {'4s': '6',
#                'Opposition': 'v England',
#                'Bat1': '49',
#                'Bat2': '0',
#                'Start Date': '7 Sep 2018',
#                'Ground': 'The Oval',
#                'BF': '71',
#                'Runs': '49',
#                '6s': '0',
#                'SR': '69.01'}),
#              ('Test # 2319',
#               {'4s': '10',
#                'Opposition': 'v West Indies',
#                'Bat1': '139',
#                'Bat2': '-',
#                'Start Date': '4 Oct 2018',
#                'Ground': 'Rajkot',
#                'BF': '230',
#                'Runs': '139',
#                '6s': '0',
#                'SR': '60.43'}),
#              ('Test # 2321',
#               {'Runs': '45',
#                'BF': '78',
#                '6s': '0',
#                'SR': '57.69',
#                '4s': '5',
#                'Opposition': 'v West Indies',
#                'Bat1': '45',
#                'Bat2': 'DNB',
#                'Start Date': '12 Oct 2018',
#                'Ground': 'Hyderabad (Deccan)'}),
#              ('Test # 2333',
#               {'4s': '3',
#                'Bat1': '3',
#                'Opposition': 'v Australia',
#                'Bat2': '34',
#                'Start Date': '6 Dec 2018',
#                'Ground': 'Adelaide',
#                'BF': '120',
#                'Runs': '37',
#                '6s': '0',
#                'SR': '30.83'}),
#              ('Test # 2334',
#               {'4s': '15',
#                'Bat1': '123',
#                'Opposition': 'v Australia',
#                'Bat2': '17',
#                'Start Date': '14 Dec 2018',
#                'Ground': 'Perth',
#                'BF': '297',
#                'Runs': '140',
#                '6s': '1',
#                'SR': '47.13'}),
#              ('Test # 2337',
#               {'4s': '9',
#                'Bat1': '82',
#                'Opposition': 'v Australia',
#                'Bat2': '0',
#                'Start Date': '26 Dec 2018',
#                'Ground': 'Melbourne',
#                'BF': '208',
#                'Runs': '82',
#                '6s': '0',
#                'SR': '39.42'}),
#              ('Test # 2339',
#               {'Start Date': '3 Jan 2019',
#                'Ground': 'Sydney',
#                'Runs': '23',
#                'BF': '59',
#                'SR': '38.98',
#                '6s': '0',
#                '4s': '4',
#                'Bat1': '23',
#                'Opposition': 'v Australia',
#                'Bat2': '-'}),
#              ('Test # 2358',
#               {'Start Date': '22 Aug 2019',
#                'Ground': 'North Sound',
#                'BF': '125',
#                'Runs': '60',
#                '6s': '0',
#                'SR': '48.00',
#                '4s': '4',
#                'Bat1': '9',
#                'Opposition': 'v West Indies',
#                'Bat2': '51'}),
#              ('Test # 2359',
#               {'4s': '10',
#                'Bat1': '76',
#                'Opposition': 'v West Indies',
#                'Bat2': '0',
#                'Start Date': '30 Aug 2019',
#                'Ground': 'Kingston',
#                'BF': '164',
#                'Runs': '76',
#                'SR': '46.34',
#                '6s': '0'}),
#              ('Test # 2363',
#               {'Start Date': '2 Oct 2019',
#                'Ground': 'Visakhapatnam',
#                'Runs': '51',
#                'BF': '65',
#                '6s': '1',
#                'SR': '78.46',
#                '4s': '7',
#                'Opposition': 'v South Africa',
#                'Bat1': '20',
#                'Bat2': '31*'}),
#              ('Test # 2364',
#               {'BF': '336',
#                'Runs': '254',
#                'SR': '75.59',
#                '6s': '2',
#                '4s': '33',
#                'Bat1': '254*',
#                'Opposition': 'v South Africa',
#                'Bat2': '-',
#                'Start Date': '10 Oct 2019',
#                'Ground': 'Pune'}),
#              ('Test # 2365',
#               {'Start Date': '19 Oct 2019',
#                'Ground': 'Ranchi',
#                'BF': '22',
#                'Runs': '12',
#                '6s': '0',
#                'SR': '54.54',
#                '4s': '2',
#                'Opposition': 'v South Africa',
#                'Bat1': '12',
#                'Bat2': '-'})])

# %%
data1 = data.copy()

# %%
data1
# Out:
# OrderedDict([('Test # 1997',
#               {'4s': '3',
#                'Bat1': '4',
#                'Opposition': 'v West Indies',
#                'Bat2': '15',
#                'Start Date': '20 Jun 2011',
#                'Ground': 'Kingston',
#                'BF': '64',
#                'Runs': '19',
#                '6s': '0',
#                'SR': '29.68'}),
#              ('Test # 1998',
#               {'BF': '109',
#                'Runs': '27',
#                'SR': '24.77',
#                '6s': '1',
#                '4s': '1',
#                'Bat1': '0',
#                'Opposition': 'v West Indies',
#                'Bat2': '27',
#                'Start Date': '28 Jun 2011',
#                'Ground': 'Bridgetown'}),
#              ('Test # 1999',
#               {'Start Date': '6 Jul 2011',
#                'Ground': 'Roseau',
#                'BF': '53',
#                'Runs': '30',
#                'SR': '56.60',
#                '6s': '0',
#                '4s': '2',
#                'Bat1': '30',
#                'Opposition': 'v West Indies',
#                'Bat2': 'DNB'}),
#              ('Test # 2019',
#               {'4s': '8',
#                'Opposition': 'v West Indies',
#                'Bat1': '52',
#                'Bat2': '63',
#                'Start Date': '22 Nov 2011',
#                'Ground': 'Mumbai',
#                'BF': '225',
#                'Runs': '115',
#                '6s': '1',
#                'SR': '51.11'}),
#              ('Test # 2025',
#               {'Start Date': '26 Dec 2011',
#                'Ground': 'Melbourne',
#                'BF': '22',
#                'Runs': '11',
#                'SR': '50.00',
#                '6s': '0',
#                '4s': '1',
#                'Bat1': '11',
#                'Opposition': 'v Australia',
#                'Bat2': '0'}),
#              ('Test # 2027',
#               {'4s': '5',
#                'Opposition': 'v Australia',
#                'Bat1': '23',
#                'Bat2': '9',
#                'Start Date': '3 Jan 2012',
#                'Ground': 'Sydney',
#                'Runs': '32',
#                'BF': '65',
#                '6s': '0',
#                'SR': '49.23'}),
#              ('Test # 2029',
#               {'4s': '15',
#                'Bat1': '44',
#                'Opposition': 'v Australia',
#                'Bat2': '75',
#                'Start Date': '13 Jan 2012',
#                'Ground': 'Perth',
#                'BF': '217',
#                'Runs': '119',
#                'SR': '54.83',
#                '6s': '0'}),
#              ('Test # 2031',
#               {'Start Date': '24 Jan 2012',
#                'Ground': 'Adelaide',
#                'BF': '275',
#                'Runs': '138',
#                '6s': '1',
#                'SR': '50.18',
#                '4s': '13',
#                'Bat1': '116',
#                'Opposition': 'v Australia',
#                'Bat2': '22'}),
#              ('Test # 2054',
#               {'4s': '8',
#                'Opposition': 'v New Zealand',
#                'Bat1': '58',
#                'Bat2': '-',
#                'Start Date': '23 Aug 2012',
#                'Ground': 'Hyderabad (Deccan)',
#                'BF': '107',
#                'Runs': '58',
#                '6s': '0',
#                'SR': '54.20'}),
#              ('Test # 2055',
#               {'Bat1': '103',
#                'Opposition': 'v New Zealand',
#                'Bat2': '51*',
#                'Start Date': '31 Aug 2012',
#                'Ground': 'Bengaluru',
#                'BF': '275',
#                'Runs': '154',
#                'SR': '56.00',
#                '6s': '1',
#                '4s': '23'}),
#              ('Test # 2058',
#               {'4s': '6',
#                'Bat1': '19',
#                'Opposition': 'v England',
#                'Bat2': '14*',
#                'Start Date': '15 Nov 2012',
#                'Ground': 'Ahmedabad',
#                'BF': '88',
#                'Runs': '33',
#                'SR': '37.50',
#                '6s': '0'}),
#              ('Test # 2062',
#               {'BF': '68',
#                'Runs': '26',
#                '6s': '0',
#                'SR': '38.23',
#                '4s': '4',
#                'Bat1': '19',
#                'Opposition': 'v England',
#                'Bat2': '7',
#                'Start Date': '23 Nov 2012',
#                'Ground': 'Mumbai'}),
#              ('Test # 2065',
#               {'4s': '4',
#                'Bat1': '6',
#                'Opposition': 'v England',
#                'Bat2': '20',
#                'Start Date': '5 Dec 2012',
#                'Ground': 'Kolkata',
#                'Runs': '26',
#                'BF': '84',
#                'SR': '30.95',
#                '6s': '0'}),
#              ('Test # 2066',
#               {'Ground': 'Nagpur',
#                'BF': '295',
#                'Runs': '103',
#                'SR': '34.91',
#                '6s': '0',
#                '4s': '11',
#                'Bat1': '103',
#                'Opposition': 'v England',
#                'Bat2': '-',
#                'Start Date': '13 Dec 2012'}),
#              ('Test # 2074',
#               {'Start Date': '22 Feb 2013',
#                'Ground': 'Chennai',
#                'Runs': '107',
#                'BF': '206',
#                '6s': '1',
#                'SR': '51.94',
#                '4s': '15',
#                'Opposition': 'v Australia',
#                'Bat1': '107',
#                'Bat2': 'DNB'}),
#              ('Test # 2076',
#               {'Ground': 'Hyderabad (Deccan)',
#                'BF': '92',
#                'Runs': '34',
#                'SR': '36.95',
#                '6s': '0',
#                '4s': '3',
#                'Bat1': '34',
#                'Opposition': 'v Australia',
#                'Bat2': '-',
#                'Start Date': '2 Mar 2013'}),
#              ('Test # 2081',
#               {'4s': '13',
#                'Bat1': '67*',
#                'Opposition': 'v Australia',
#                'Bat2': '34',
#                'Start Date': '14 Mar 2013',
#                'Ground': 'Mohali',
#                'BF': '190',
#                'Runs': '101',
#                '6s': '1',
#                'SR': '53.15'}),
#              ('Test # 2085',
#               {'Start Date': '22 Mar 2013',
#                'Ground': 'Delhi',
#                'BF': '68',
#                'Runs': '42',
#                'SR': '61.76',
#                '6s': '0',
#                '4s': '4',
#                'Bat1': '1',
#                'Opposition': 'v Australia',
#                'Bat2': '41'}),
#              ('Test # 2101',
#               {'Start Date': '6 Nov 2013',
#                'Ground': 'Kolkata',
#                'Runs': '3',
#                'BF': '5',
#                '6s': '0',
#                'SR': '60.00',
#                '4s': '0',
#                'Opposition': 'v West Indies',
#                'Bat1': '3',
#                'Bat2': '-'}),
#              ('Test # 2102',
#               {'4s': '5',
#                'Opposition': 'v West Indies',
#                'Bat1': '57',
#                'Bat2': '-',
#                'Start Date': '14 Nov 2013',
#                'Ground': 'Mumbai',
#                'BF': '78',
#                'Runs': '57',
#                '6s': '0',
#                'SR': '73.07'}),
#              ('Test # 2108',
#               {'Start Date': '18 Dec 2013',
#                'Ground': 'Johannesburg',
#                'BF': '374',
#                'Runs': '215',
#                'SR': '57.48',
#                '6s': '0',
#                '4s': '27',
#                'Bat1': '119',
#                'Opposition': 'v South Africa',
#                'Bat2': '96'}),
#              ('Test # 2111',
#               {'4s': '6',
#                'Bat1': '46',
#                'Opposition': 'v South Africa',
#                'Bat2': '11',
#                'Start Date': '26 Dec 2013',
#                'Ground': 'Durban',
#                'Runs': '57',
#                'BF': '114',
#                'SR': '50.00',
#                '6s': '0'}),
#              ('Test # 2118',
#               {'Start Date': '6 Feb 2014',
#                'Ground': 'Auckland',
#                'BF': '115',
#                'Runs': '71',
#                '6s': '0',
#                'SR': '61.73',
#                '4s': '13',
#                'Opposition': 'v New Zealand',
#                'Bat1': '4',
#                'Bat2': '67'}),
#              ('Test # 2120',
#               {'Start Date': '14 Feb 2014',
#                'Ground': 'Wellington',
#                'BF': '228',
#                'Runs': '143',
#                '6s': '1',
#                'SR': '62.71',
#                '4s': '19',
#                'Bat1': '38',
#                'Opposition': 'v New Zealand',
#                'Bat2': '105*'}),
#              ('Test # 2128',
#               {'4s': '1',
#                'Bat1': '1',
#                'Opposition': 'v England',
#                'Bat2': '8',
#                'Start Date': '9 Jul 2014',
#                'Ground': 'Nottingham',
#                'BF': '37',
#                'Runs': '9',
#                '6s': '0',
#                'SR': '24.32'}),
#              ('Test # 2130',
#               {'BF': '35',
#                'Runs': '25',
#                'SR': '71.42',
#                '6s': '0',
#                '4s': '4',
#                'Bat1': '25',
#                'Opposition': 'v England',
#                'Bat2': '0',
#                'Start Date': '17 Jul 2014',
#                'Ground': "Lord's"}),
#              ('Test # 2132',
#               {'4s': '6',
#                'Bat1': '39',
#                'Opposition': 'v England',
#                'Bat2': '28',
#                'Start Date': '27 Jul 2014',
#                'Ground': 'Southampton',
#                'BF': '131',
#                'Runs': '67',
#                '6s': '0',
#                'SR': '51.14'}),
#              ('Test # 2134',
#               {'Start Date': '7 Aug 2014',
#                'Ground': 'Manchester',
#                'BF': '13',
#                'Runs': '7',
#                '6s': '0',
#                'SR': '53.84',
#                '4s': '1',
#                'Bat1': '0',
#                'Opposition': 'v England',
#                'Bat2': '7'}),
#              ('Test # 2137',
#               {'4s': '3',
#                'Opposition': 'v England',
#                'Bat1': '6',
#                'Bat2': '20',
#                'Start Date': '15 Aug 2014',
#                'Ground': 'The Oval',
#                'Runs': '26',
#                'BF': '72',
#                '6s': '0',
#                'SR': '36.11'}),
#              ('Test # 2148',
#               {'4s': '28',
#                'Opposition': 'v Australia',
#                'Bat1': '115',
#                'Bat2': '141',
#                'Start Date': '9 Dec 2014',
#                'Ground': 'Adelaide',
#                'Runs': '256',
#                'BF': '359',
#                '6s': '1',
#                'SR': '71.30'}),
#              ('Test # 2149',
#               {'4s': '1',
#                'Bat1': '19',
#                'Opposition': 'v Australia',
#                'Bat2': '1',
#                'Start Date': '17 Dec 2014',
#                'Ground': 'Brisbane',
#                'Runs': '20',
#                'BF': '38',
#                'SR': '52.63',
#                '6s': '0'}),
#              ('Test # 2152',
#               {'4s': '25',
#                'Bat1': '169',
#                'Opposition': 'v Australia',
#                'Bat2': '54',
#                'Start Date': '26 Dec 2014',
#                'Ground': 'Melbourne',
#                'Runs': '223',
#                'BF': '371',
#                'SR': '60.10',
#                '6s': '0'}),
#              ('Test # 2156',
#               {'4s': '23',
#                'Bat1': '147',
#                'Opposition': 'v Australia',
#                'Bat2': '46',
#                'Start Date': '6 Jan 2015',
#                'Ground': 'Sydney',
#                'BF': '325',
#                'Runs': '193',
#                'SR': '59.38',
#                '6s': '0'}),
#              ('Test # 2165',
#               {'4s': '2',
#                'Bat1': '14',
#                'Opposition': 'v Bangladesh',
#                'Bat2': '-',
#                'Start Date': '10 Jun 2015',
#                'Ground': 'Fatullah',
#                'Runs': '14',
#                'BF': '22',
#                'SR': '63.63',
#                '6s': '0'}),
#              ('Test # 2176',
#               {'4s': '11',
#                'Bat1': '103',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '3',
#                'Start Date': '12 Aug 2015',
#                'Ground': 'Galle',
#                'BF': '201',
#                'Runs': '106',
#                'SR': '52.73',
#                '6s': '0'}),
#              ('Test # 2177',
#               {'Bat1': '78',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '10',
#                'Start Date': '20 Aug 2015',
#                'Ground': 'Colombo (PSS)',
#                'BF': '126',
#                'Runs': '88',
#                '6s': '1',
#                'SR': '69.84',
#                '4s': '8'}),
#              ('Test # 2179',
#               {'BF': '123',
#                'Runs': '39',
#                'SR': '31.70',
#                '6s': '0',
#                '4s': '5',
#                'Bat1': '18',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '21',
#                'Start Date': '28 Aug 2015',
#                'Ground': 'Colombo (SSC)'}),
#              ('Test # 2186',
#               {'Runs': '30',
#                'BF': '75',
#                'SR': '40.00',
#                '6s': '0',
#                '4s': '4',
#                'Bat1': '1',
#                'Opposition': 'v South Africa',
#                'Bat2': '29',
#                'Start Date': '5 Nov 2015',
#                'Ground': 'Mohali'}),
#              ('Test # 2188',
#               {'BF': '-',
#                'Runs': '-',
#                'SR': '-',
#                '6s': '-',
#                '4s': '-',
#                'Bat1': 'DNB',
#                'Opposition': 'v South Africa',
#                'Bat2': '-',
#                'Start Date': '14 Nov 2015',
#                'Ground': 'Bengaluru'}),
#              ('Test # 2189',
#               {'4s': '4',
#                'Opposition': 'v South Africa',
#                'Bat1': '22',
#                'Bat2': '16',
#                'Start Date': '25 Nov 2015',
#                'Ground': 'Nagpur',
#                'BF': '85',
#                'Runs': '38',
#                '6s': '0',
#                'SR': '44.70'}),
#              ('Test # 2191',
#               {'4s': '17',
#                'Bat1': '44',
#                'Opposition': 'v South Africa',
#                'Bat2': '88',
#                'Start Date': '3 Dec 2015',
#                'Ground': 'Delhi',
#                'BF': '227',
#                'Runs': '132',
#                '6s': '0',
#                'SR': '58.14'}),
#              ('Test # 2207',
#               {'Bat1': '200',
#                'Opposition': 'v West Indies',
#                'Bat2': '-',
#                'Start Date': '21 Jul 2016',
#                'Ground': 'North Sound',
#                'BF': '283',
#                'Runs': '200',
#                'SR': '70.67',
#                '6s': '0',
#                '4s': '24'}),
#              ('Test # 2211',
#               {'BF': '90',
#                'Runs': '44',
#                'SR': '48.88',
#                '6s': '1',
#                '4s': '4',
#                'Bat1': '44',
#                'Opposition': 'v West Indies',
#                'Bat2': '-',
#                'Start Date': '30 Jul 2016',
#                'Ground': 'Kingston'}),
#              ('Test # 2215',
#               {'4s': '0',
#                'Bat1': '3',
#                'Opposition': 'v West Indies',
#                'Bat2': '4',
#                'Start Date': '9 Aug 2016',
#                'Ground': 'Gros Islet',
#                'BF': '25',
#                'Runs': '7',
#                '6s': '0',
#                'SR': '28.00'}),
#              ('Test # 2218',
#               {'Start Date': '18 Aug 2016',
#                'Ground': 'Port of Spain',
#                'Runs': '-',
#                'BF': '-',
#                'SR': '-',
#                '6s': '-',
#                '4s': '-',
#                'Bat1': 'TDNB',
#                'Opposition': 'v West Indies',
#                'Bat2': '-'}),
#              ('Test # 2221',
#               {'4s': '5',
#                'Opposition': 'v New Zealand',
#                'Bat1': '9',
#                'Bat2': '18',
#                'Start Date': '22 Sep 2016',
#                'Ground': 'Kanpur',
#                'BF': '50',
#                'Runs': '27',
#                '6s': '0',
#                'SR': '54.00'}),
#              ('Test # 2222',
#               {'Ground': 'Kolkata',
#                'BF': '93',
#                'Runs': '54',
#                'SR': '58.06',
#                '6s': '0',
#                '4s': '8',
#                'Bat1': '9',
#                'Opposition': 'v New Zealand',
#                'Bat2': '45',
#                'Start Date': '30 Sep 2016'}),
#              ('Test # 2223',
#               {'Bat1': '211',
#                'Opposition': 'v New Zealand',
#                'Bat2': '17',
#                'Start Date': '8 Oct 2016',
#                'Ground': 'Indore',
#                'BF': '394',
#                'Runs': '228',
#                '6s': '0',
#                'SR': '57.86',
#                '4s': '21'}),
#              ('Test # 2232',
#               {'Start Date': '9 Nov 2016',
#                'Ground': 'Rajkot',
#                'Runs': '89',
#                'BF': '193',
#                'SR': '46.11',
#                '6s': '0',
#                '4s': '11',
#                'Bat1': '40',
#                'Opposition': 'v England',
#                'Bat2': '49*'}),
#              ('Test # 2235',
#               {'Start Date': '17 Nov 2016',
#                'Ground': 'Visakhapatnam',
#                'BF': '376',
#                'Runs': '248',
#                '6s': '0',
#                'SR': '65.95',
#                '4s': '26',
#                'Bat1': '167',
#                'Opposition': 'v England',
#                'Bat2': '81'}),
#              ('Test # 2238',
#               {'BF': '138',
#                'Runs': '68',
#                'SR': '49.27',
#                '6s': '0',
#                '4s': '9',
#                'Bat1': '62',
#                'Opposition': 'v England',
#                'Bat2': '6*',
#                'Start Date': '26 Nov 2016',
#                'Ground': 'Mohali'}),
#              ('Test # 2239',
#               {'Ground': 'Mumbai',
#                'BF': '340',
#                'Runs': '235',
#                'SR': '69.11',
#                '6s': '1',
#                '4s': '25',
#                'Bat1': '235',
#                'Opposition': 'v England',
#                'Bat2': '-',
#                'Start Date': '8 Dec 2016'}),
#              ('Test # 2241',
#               {'Ground': 'Chennai',
#                'BF': '29',
#                'Runs': '15',
#                '6s': '0',
#                'SR': '51.72',
#                '4s': '1',
#                'Bat1': '15',
#                'Opposition': 'v England',
#                'Bat2': '-',
#                'Start Date': '16 Dec 2016'}),
#              ('Test # 2249',
#               {'4s': '26',
#                'Bat1': '204',
#                'Opposition': 'v Bangladesh',
#                'Bat2': '38',
#                'Start Date': '9 Feb 2017',
#                'Ground': 'Hyderabad (Deccan)',
#                'BF': '286',
#                'Runs': '242',
#                '6s': '1',
#                'SR': '84.61'}),
#              ('Test # 2250',
#               {'Opposition': 'v Australia',
#                'Bat1': '0',
#                'Bat2': '13',
#                'Start Date': '23 Feb 2017',
#                'Ground': 'Pune',
#                'BF': '39',
#                'Runs': '13',
#                '6s': '0',
#                'SR': '33.33',
#                '4s': '1'}),
#              ('Test # 2251',
#               {'4s': '3',
#                'Opposition': 'v Australia',
#                'Bat1': '12',
#                'Bat2': '15',
#                'Start Date': '4 Mar 2017',
#                'Ground': 'Bengaluru',
#                'BF': '42',
#                'Runs': '27',
#                '6s': '0',
#                'SR': '64.28'}),
#              ('Test # 2256',
#               {'BF': '23',
#                'Runs': '6',
#                'SR': '26.08',
#                '6s': '0',
#                '4s': '0',
#                'Bat1': '6',
#                'Opposition': 'v Australia',
#                'Bat2': '-',
#                'Start Date': '16 Mar 2017',
#                'Ground': 'Ranchi'}),
#              ('Test # 2265',
#               {'Start Date': '26 Jul 2017',
#                'Ground': 'Galle',
#                'BF': '144',
#                'Runs': '106',
#                'SR': '73.61',
#                '6s': '1',
#                '4s': '5',
#                'Bat1': '3',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '103*'}),
#              ('Test # 2267',
#               {'Start Date': '3 Aug 2017',
#                'Ground': 'Colombo (SSC)',
#                'BF': '29',
#                'Runs': '13',
#                '6s': '0',
#                'SR': '44.82',
#                '4s': '2',
#                'Bat1': '13',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '-'}),
#              ('Test # 2269',
#               {'BF': '84',
#                'Runs': '42',
#                'SR': '50.00',
#                '6s': '0',
#                '4s': '3',
#                'Bat1': '42',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '-',
#                'Start Date': '12 Aug 2017',
#                'Ground': 'Pallekele'}),
#              ('Test # 2281',
#               {'Ground': 'Kolkata',
#                'BF': '130',
#                'Runs': '104',
#                '6s': '2',
#                'SR': '80.00',
#                '4s': '12',
#                'Bat1': '0',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '104*',
#                'Start Date': '16 Nov 2017'}),
#              ('Test # 2283',
#               {'4s': '17',
#                'Bat1': '213',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '-',
#                'Start Date': '24 Nov 2017',
#                'Ground': 'Nagpur',
#                'BF': '267',
#                'Runs': '213',
#                '6s': '2',
#                'SR': '79.77'}),
#              ('Test # 2286',
#               {'4s': '28',
#                'Bat1': '243',
#                'Opposition': 'v Sri Lanka',
#                'Bat2': '50',
#                'Start Date': '2 Dec 2017',
#                'Ground': 'Delhi',
#                'BF': '345',
#                'Runs': '293',
#                'SR': '84.92',
#                '6s': '0'}),
#              ('Test # 2292',
#               {'Opposition': 'v South Africa',
#                'Bat1': '5',
#                'Bat2': '28',
#                'Start Date': '5 Jan 2018',
#                'Ground': 'Cape Town',
#                'Runs': '33',
#                'BF': '53',
#                '6s': '0',
#                'SR': '62.26',
#                '4s': '4'}),
#              ('Test # 2293',
#               {'Start Date': '13 Jan 2018',
#                'Ground': 'Centurion',
#                'BF': '237',
#                'Runs': '158',
#                'SR': '66.66',
#                '6s': '0',
#                '4s': '16',
#                'Bat1': '153',
#                'Opposition': 'v South Africa',
#                'Bat2': '5'}),
#              ('Test # 2294',
#               {'BF': '185',
#                'Runs': '95',
#                'SR': '51.35',
#                '6s': '0',
#                '4s': '15',
#                'Bat1': '54',
#                'Opposition': 'v South Africa',
#                'Bat2': '41',
#                'Start Date': '24 Jan 2018',
#                'Ground': 'Johannesburg'}),
#              ('Test # 2314',
#               {'Bat1': '149',
#                'Opposition': 'v England',
#                'Bat2': '51',
#                'Start Date': '1 Aug 2018',
#                'Ground': 'Birmingham',
#                'BF': '318',
#                'Runs': '200',
#                '6s': '1',
#                'SR': '62.89',
#                '4s': '26'}),
#              ('Test # 2315',
#               {'BF': '86',
#                'Runs': '40',
#                'SR': '46.51',
#                '6s': '0',
#                '4s': '4',
#                'Bat1': '23',
#                'Opposition': 'v England',
#                'Bat2': '17',
#                'Start Date': '9 Aug 2018',
#                'Ground': "Lord's"}),
#              ('Test # 2316',
#               {'Bat1': '97',
#                'Opposition': 'v England',
#                'Bat2': '103',
#                'Start Date': '18 Aug 2018',
#                'Ground': 'Nottingham',
#                'BF': '349',
#                'Runs': '200',
#                'SR': '57.30',
#                '6s': '0',
#                '4s': '21'}),
#              ('Test # 2317',
#               {'Start Date': '30 Aug 2018',
#                'Ground': 'Southampton',
#                'Runs': '104',
#                'BF': '201',
#                '6s': '0',
#                'SR': '51.74',
#                '4s': '10',
#                'Opposition': 'v England',
#                'Bat1': '46',
#                'Bat2': '58'}),
#              ('Test # 2318',
#               {'4s': '6',
#                'Opposition': 'v England',
#                'Bat1': '49',
#                'Bat2': '0',
#                'Start Date': '7 Sep 2018',
#                'Ground': 'The Oval',
#                'BF': '71',
#                'Runs': '49',
#                '6s': '0',
#                'SR': '69.01'}),
#              ('Test # 2319',
#               {'4s': '10',
#                'Opposition': 'v West Indies',
#                'Bat1': '139',
#                'Bat2': '-',
#                'Start Date': '4 Oct 2018',
#                'Ground': 'Rajkot',
#                'BF': '230',
#                'Runs': '139',
#                '6s': '0',
#                'SR': '60.43'}),
#              ('Test # 2321',
#               {'Runs': '45',
#                'BF': '78',
#                '6s': '0',
#                'SR': '57.69',
#                '4s': '5',
#                'Opposition': 'v West Indies',
#                'Bat1': '45',
#                'Bat2': 'DNB',
#                'Start Date': '12 Oct 2018',
#                'Ground': 'Hyderabad (Deccan)'}),
#              ('Test # 2333',
#               {'4s': '3',
#                'Bat1': '3',
#                'Opposition': 'v Australia',
#                'Bat2': '34',
#                'Start Date': '6 Dec 2018',
#                'Ground': 'Adelaide',
#                'BF': '120',
#                'Runs': '37',
#                '6s': '0',
#                'SR': '30.83'}),
#              ('Test # 2334',
#               {'4s': '15',
#                'Bat1': '123',
#                'Opposition': 'v Australia',
#                'Bat2': '17',
#                'Start Date': '14 Dec 2018',
#                'Ground': 'Perth',
#                'BF': '297',
#                'Runs': '140',
#                '6s': '1',
#                'SR': '47.13'}),
#              ('Test # 2337',
#               {'4s': '9',
#                'Bat1': '82',
#                'Opposition': 'v Australia',
#                'Bat2': '0',
#                'Start Date': '26 Dec 2018',
#                'Ground': 'Melbourne',
#                'BF': '208',
#                'Runs': '82',
#                '6s': '0',
#                'SR': '39.42'}),
#              ('Test # 2339',
#               {'Start Date': '3 Jan 2019',
#                'Ground': 'Sydney',
#                'Runs': '23',
#                'BF': '59',
#                'SR': '38.98',
#                '6s': '0',
#                '4s': '4',
#                'Bat1': '23',
#                'Opposition': 'v Australia',
#                'Bat2': '-'}),
#              ('Test # 2358',
#               {'Start Date': '22 Aug 2019',
#                'Ground': 'North Sound',
#                'BF': '125',
#                'Runs': '60',
#                '6s': '0',
#                'SR': '48.00',
#                '4s': '4',
#                'Bat1': '9',
#                'Opposition': 'v West Indies',
#                'Bat2': '51'}),
#              ('Test # 2359',
#               {'4s': '10',
#                'Bat1': '76',
#                'Opposition': 'v West Indies',
#                'Bat2': '0',
#                'Start Date': '30 Aug 2019',
#                'Ground': 'Kingston',
#                'BF': '164',
#                'Runs': '76',
#                'SR': '46.34',
#                '6s': '0'}),
#              ('Test # 2363',
#               {'Start Date': '2 Oct 2019',
#                'Ground': 'Visakhapatnam',
#                'Runs': '51',
#                'BF': '65',
#                '6s': '1',
#                'SR': '78.46',
#                '4s': '7',
#                'Opposition': 'v South Africa',
#                'Bat1': '20',
#                'Bat2': '31*'}),
#              ('Test # 2364',
#               {'BF': '336',
#                'Runs': '254',
#                'SR': '75.59',
#                '6s': '2',
#                '4s': '33',
#                'Bat1': '254*',
#                'Opposition': 'v South Africa',
#                'Bat2': '-',
#                'Start Date': '10 Oct 2019',
#                'Ground': 'Pune'}),
#              ('Test # 2365',
#               {'Start Date': '19 Oct 2019',
#                'Ground': 'Ranchi',
#                'BF': '22',
#                'Runs': '12',
#                '6s': '0',
#                'SR': '54.54',
#                '4s': '2',
#                'Opposition': 'v South Africa',
#                'Bat1': '12',
#                'Bat2': '-'})])
